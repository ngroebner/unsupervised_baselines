# %% [markdown]
# # Investigate repeaters

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import obspy

# %%
path = "/Users/nate/datasets/repeaters/felix_res1/"
clusters = pd.read_csv(os.path.join(path, "groundtruth_clusters.csv"))
res1cat = pd.read_csv(os.path.join(path,"RES1_5km.cat"), header=None, delim_whitespace=True)
all_sequences = pd.read_csv(os.path.join(path,"all_sequences.csv"))

# %%
waves = obspy.Stream([obspy.read(os.path.join(path,"BAV.waves_20s",fname)) for fname in os.listdir(path+"BAV.waves") if fname not in [".",".."]])

# %%
waves[29].plot()
plt.show()
